# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get('http://www.bmhim.com/')

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
#box = soup.findAll('div', class_='col-12 col-md-6 col-lg-8')

# %%
title = soup.findAll('div', class_='col-sm-12')

# %%
print(title)
# Out:
# [<div class="col-sm-12">
# <button class="navbar-toggle" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <div class="collapse navbar-collapse pull-left" id="bs-example-navbar-collapse-1" style="max-height:none; width:100%">
# <ul class="nav navbar-nav" style="width: 100%;">
# <li>
# <a class="active" href="index.php">INICIO<br/><i>HOME</i></a>
# </li>
# <li><a href=" #">LEER<br/><i>BROWSE</i></a><ul class="submenu"><li><a href="index.php#actual">NÚMERO ACTUAL / CURRENT ISSUE</a></li>
# <li><a href="index.php#archivo">ARCHIVO / JOURNAL ARCHIVE</a></li>
# <li><a href="inpress.php">AVANCE ONLINE / AHEAD OF PRINT</a></li>
# <li><a href="registration.php">TOC ALERT</a></li>
# ...
